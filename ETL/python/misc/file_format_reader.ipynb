# %%
import sys, os
sys.path.insert(0, "/Users/abhi/myRepos/ecom_app")
os.chdir("/Users/abhi/myRepos/ecom_app")

# %%
from pyspark.sql import functions as F
from ETL.python.utils.spark_utils import read_table, write_table, get_spark_session

# %%
spark = get_spark_session()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/13 18:39:58 WARN Utils: Your hostname, Abhisheks-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.0.0.2 instead (on interface en0)
# 26/06/13 18:39:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/opt/miniconda3/envs/.ecom_app_py310/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/abhi/.ivy2.5.2/cache
# The jars for the packages stored in: /Users/abhi/.ivy2.5.2/jars
# io.dataflint#dataflint-spark4_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-8ca994dc-7d24-4d76-b621-43cf4f3eb421;1.0
# 	confs: [default]
# 	found io.dataflint#dataflint-spark4_2.13;0.9.9 in central
# ...

# %%
df1 = spark.read.parquet('data/user_name_baseline.parquet')
df1.filter(F.col('location') == 'Chicago').show()
# Out:
# +---------+-------+--------+
# |  user_id|   name|location|
# +---------+-------+--------+
# |833333334|  Diana| Chicago|
# |833333335|  Frank| Chicago|
# |833333337|   Iris| Chicago|
# |833333339|  Grace| Chicago|
# |833333342|  Grace| Chicago|
# |833333344|  Diana| Chicago|
# |833333345|  Henry| Chicago|
# |833333348|    Bob| Chicago|
# |833333349|  Henry| Chicago|
# |833333351|   Jack| Chicago|
# |833333354|    Eve| Chicago|
# |833333355|    Bob| Chicago|
# |833333360|    Eve| Chicago|
# |833333362|Charlie| Chicago|
# |833333363|  Alice| Chicago|
# |833333366|  Diana| Chicago|
# |833333369|  Henry| Chicago|
# |833333383|Charlie| Chicago|
# |833333384|  Henry| Chicago|
# |833333390|   Iris| Chicago|
# +---------+-------+--------+
# only showing top 20 rows

# %%
df2 = spark.read.parquet('data/user_name_orderby_location.parquet')
df2.filter(F.col('location') == 'Chicago').show()
# Out:
# +---------+-------+--------+
# |  user_id|   name|location|
# +---------+-------+--------+
# |        2|  Diana| Chicago|
# |990219302|   Iris| Chicago|
# |        5|    Eve| Chicago|
# |990219305|  Diana| Chicago|
# |        9|  Diana| Chicago|
# |990219308|  Alice| Chicago|
# |       11|  Grace| Chicago|
# |990219310|  Henry| Chicago|
# |       12|  Alice| Chicago|
# |990219313|    Eve| Chicago|
# |       13|  Grace| Chicago|
# |990219315|  Henry| Chicago|
# |       15|  Henry| Chicago|
# |990219316|  Henry| Chicago|
# |       19|  Grace| Chicago|
# |990219320|Charlie| Chicago|
# |       20|Charlie| Chicago|
# |990219322|Charlie| Chicago|
# |       24|  Grace| Chicago|
# |990219326|   Iris| Chicago|
# +---------+-------+--------+
# only showing top 20 rows

# %%
print(spark.sparkContext.uiWebUrl)
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File /opt/miniconda3/envs/.ecom_app_py310/lib/python3.10/site-packages/py4j/clientserver.py:527, in ClientServerConnection.send_command(self, command)
#     526 try:
# --> 527     self.socket.sendall(command.encode("utf-8"))
#     528 except Exception as e:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# File /opt/miniconda3/envs/.ecom_app_py310/lib/python3.10/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# ...
